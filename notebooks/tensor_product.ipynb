# %%
import numpy as np
import jax.numpy as jnp
import jax
import jax.random as jr
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import rho_plus as rp
import wat

is_dark = False
theme, cs = rp.mpl_setup(is_dark)
rp.plotly_setup(is_dark)

# %%
import e3nn_jax as e3nn
from e3nn_jax import Irreps, IrrepsArray

rng = jr.key(29205)

sh_irreps = '0e + 1o + 2e + 3o + 4e + 5o + 6e'

ir_out = sum(e3nn.Irrep.iterator(4), start=e3nn.Irrep('0e'))


x = e3nn.normal('128x0e + 64x1o + 32x2e', rng, (32,1), normalize=False)
y = e3nn.normal('1o', rng, (32,4), normalize=True, normalization='norm')
y_sh = e3nn.spherical_harmonics(sh_irreps, y, normalize=True)
y_sh.array.shape
# Out:
# (32, 4, 49)

# %%
from cdv.utils import debug_structure, debug_stat
@jax.jit
def tp_standard(x, y):
    y_sh = e3nn.spherical_harmonics(sh_irreps, y, normalize=False)
    return e3nn.tensor_product(x, y_sh, filter_ir_out=ir_out)

out = {}
out['standard'] = tp_standard(x, y)
e3nn.mean(e3nn.norm(out['standard']))
# Out:
# 1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e
# [0.79078025 1.4910177  1.5319812  1.9508361  2.0144486  2.307917
#  2.3939414  2.616518   2.7189445 ]

# %%
# %%timeit

jax.block_until_ready(tp_standard(x, y))
# Out:
# 206 μs ± 4.16 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
from e3nn_jax.experimental.linear_shtp import shtp
from functools import partial

@jax.jit
def tp_so2(x, y):    
    @partial(e3nn.vmap, in_axes=(None, 1), out_axes=1)    
    @partial(e3nn.vmap, in_axes=(0, 0))    
    def inner_shtp(xi, yi):
        return shtp(xi, yi, ir_out)
    
    return inner_shtp(x[:, 0], y)

out['so2'] = tp_so2(x, y)

debug_structure(out);
# Out:
# arg0
# ├── so2
# │   └── Irreps(224x0e+320x1o+96x1e+352x2e+128x2o+352x3o+128x3e+352x4e+128x4o)[f32[32, 4, 11552]]
# └── standard
#     └── Irreps(224x0e+320x1o+96x1e+352x2e+128x2o+352x3o+128x3e+352x4e+128x4o)[f32[32, 4, 11552]]

# %%
# %%timeit

jax.block_until_ready(tp_so2(x, y))
# Out:
# 438 μs ± 2.32 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
@jax.jit
def tp_sh(x, y): 
    return e3nn.tensor_product_with_spherical_harmonics(x, y, degree=Irreps(sh_irreps).lmax).filter(lmax=4)

out['tpsh'] = tp_sh(x, y)

# %%
# %%timeit

jax.block_until_ready(tp_sh(x, y))
# Out:
# 649 μs ± 2.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
from functools import reduce
{
    k: e3nn.mean(e3nn.norm(v))
    for k, v in out.items()
}
# Out:
# {'standard': 1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e
#  [0.79078025 1.4910177  1.5319812  1.9508361  2.0144486  2.307917
#   2.3939414  2.616518   2.7189445 ],
#  'so2': 1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e
#  [0.7908689  0.92872524 1.2502549  0.95677906 1.2463126  0.95678645
#   1.2462797  0.9567873  1.2462709 ],
#  'tpsh': 1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e+1x0e
#  [0.7908688 1.4911186 1.5320606 1.9495199 2.0145316 2.306254  2.3937762
#   2.6144505 2.7187533]}

# %%
z1 = out['standard']
z2 = out['so2']

z1.filter('1o')[0].array / z2.filter('1o')[0].array
# Out:
# Array([[ 1.7305142 ,  1.7315321 ,  1.7308031 , ..., -0.7276232 ,
#         -0.6896798 , -0.97105074],
#        [ 1.7305272 ,  1.731149  ,  1.7306291 , ..., -0.6879926 ,
#         -0.9553743 , -0.69765127],
#        [ 1.7302281 ,  1.7318865 ,  1.7311018 , ..., -3.4879332 ,
#         -1.022996  , -0.14467084],
#        [ 1.7309673 ,  1.7316449 ,  1.7303954 , ..., -3.8500829 ,
#         -0.75589716, -0.7644943 ]], dtype=float32)

# %% [markdown]
# # Weighted Tensor Product

# %%
sh_irreps = '0e + 1o + 2e + 3o + 4e'

ir_out = sum(e3nn.Irrep.iterator(4), start=e3nn.Irrep('0e'))


x = e3nn.normal('128x0e + 64x1o + 32x2e', rng, (32,1), normalize=False)
y = e3nn.normal('1o', rng, (32,4), normalize=True, normalization='norm')
y_sh = e3nn.spherical_harmonics(sh_irreps, y, normalize=True)
z_ir = e3nn.tensor_product(x.irreps, y_sh.irreps, filter_ir_out=ir_out)
print(x.shape, y_sh.shape, z_ir.dim)
# Out:
# (32, 1, 480) (32, 4, 25) 10176

# %%
z = e3nn.tensor_product(x, y_sh, filter_ir_out=ir_out)
z.shape
# Out:
# (32, 4, 10176)

# %%
z_ir
# Out:
# 224x0e+320x1o+96x1e+352x2e+128x2o+320x3o+128x3e+256x4e+96x4o

# %%
flin = e3nn.FunctionalLinear(z_ir, x.irreps)
w = jr.normal(rng, (32, 4, flin.num_weights))


@jax.jit
def tpw(x, y_sh, w):
    flin = e3nn.FunctionalLinear(z_ir, x.irreps)
    z = e3nn.tensor_product(x, y_sh, filter_ir_out=ir_out)
    o = e3nn.vmap(e3nn.vmap(flin))(w, z)
    return o


o = tpw(x, y_sh, w)
o
# Out:
# 128x0e+64x1o+32x2e
# [[[-1.4129685   1.1402715   0.25504923 ...  1.8924981  -0.00531835
#    -1.8662033 ]
#   [-1.0756253   1.0809479  -0.05144887 ... -0.60608894  1.2200073
#    -0.36909977]
#   [-1.2273952   0.76915544  0.49694243 ... -1.0615445  -0.20397419
#    -0.42872605]
#   [ 0.1639668   1.3861811  -0.6238708  ...  1.0226527   0.8628838
#     1.4443743 ]]
#
#  [[ 1.7903879   0.3035054  -0.33021867 ...  1.1557155   0.44907847
#    -0.3035723 ]
#   [-0.9015899  -0.64314073  1.881139   ...  0.68339175 -0.36422247
#     0.6404423 ]
#   [ 0.18454598  1.3068503  -0.27890283 ...  0.1611563   1.7762641
#     0.01823836]
#   [-1.0667871  -0.4293332   1.1588671  ... -0.01767952  0.8883663
#    -0.06292846]]
#
#  [[-1.0441962  -0.82064533  2.5622804  ...  0.8163843   0.57320595
#     0.47717857]
#   [-0.81432915 -0.646554   -0.01390615 ... -0.5682297  -1.1935803
#    -1.1351529 ]
#   [ 0.03235404  0.6888337   0.55429244 ... -0.5925441  -1.1648116
#    -0.15122524]
#   [-1.4448063   0.7323848  -1.0343683  ...  0.95806503  0.33416122
#     0.48580942]]
#
#  ...
#
#  [[-1.2726464  -1.0756843   0.15209852 ... -0.38982862  1.5268222
#    -0.23101406]
#   [ 1.4197904   0.09558976 -0.6729441  ...  0.21663351  0.20190527
#    -0.10502876]
#   [-0.48947638  1.652702    1.4414942  ...  0.47362015  0.98309493
#    -0.6914525 ]
#   [-0.3500992   0.16721585  0.9382036  ...  2.328699   -1.4425057
#     0.36594754]]
#
#  [[-0.97484785  0.23121956  1.3333743  ... -0.10268974  0.14824034
#     0.98347235]
#   [ 1.0938424   0.3320046   0.41413873 ...  0.23785211  0.36735326
#    -0.45801136]
#   [ 1.6010091   1.4446285   1.6759163  ...  1.2855462   1.2577769
#    -1.0514076 ]
#   [-0.85489213 -0.05743066 -2.2297297  ...  1.6813011   0.04537582
#    -1.9788139 ]]
#
#  [[ 0.11405558 -0.32854667  0.79309237 ... -0.0802509  -0.94238317
#    -0.1129413 ]
#   [-0.35131356  0.6743251  -1.4313391  ... -1.6095177   1.100594
#    -1.4025607 ]
#   [ 1.1606553   0.194636    0.19943134 ... -0.90043294 -0.3870725
#     0.5390224 ]
#   [-0.620988    1.2370741  -0.2045283  ... -0.4839669  -0.00947696
#     0.15402739]]]

# %%
# %%timeit

jax.block_until_ready(tpw(x, y_sh, w))
# Out:
# 273 μs ± 1.11 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
from e3nn_jax.legacy import FunctionalTensorProduct

e3nn.tens
# Out:
# Init signature:
# FunctionalTensorProduct(
#     irreps_in1: e3nn_jax._src.irreps.Irreps,
#     irreps_in2: e3nn_jax._src.irreps.Irreps,
#     irreps_out: e3nn_jax._src.irreps.Irreps,
#     instructions: List[Tuple[int, int, int, str, bool, Optional[float]]],
#     in1_var: Optional[List[float]] = None,
#     in2_var: Optional[List[float]] = None,
#     out_var: Optional[List[float]] = None,
#     irrep_normalization: str = None,
#     path_normalization: Union[str, float] = None,
#     gradient_normalization: Union[str, float] = None,
# )
# Docstring:
# Tensor product of two tensors.
#
# Args:
#     irreps_in1: :class:`~e3nn_jax.Irreps` of the first tensor.
#     irreps_in2: :class:`~e3nn_jax.Irreps` of the second tensor.
#     irreps_out: :class:`~e3nn_jax.Irreps` of the output tensor.
#     instructions: List of instructions.
#         ``[(i_in1, i_in2, i_out, connection_mode, has_weight, (path_weight)), ...]``
#         - i_in1, i_in2, i_out are indices of the irreps_in1, irreps_in2, irreps_out.
#         - connection_mode is one of ``uvw``, ``uvu``, ``uvv``, ``uuw``, ``uuu``, ``uvuv``
#         - has_weight is a boolean indicating whether the instruction has a weight.
#         - path_weight (optional, 1.0 by default) is the weight of the path.
#
#     in1_var: Variance of the first tensor.
#     in2_var: Variance of the second tensor.
#     out_var: Variance of the output tensor.
#     irrep_normalization: Normalization of the tensors. ``component`` or ``norm``.
#     path_normalization (str or float): Normalization of the paths, ``element`` or ``path``.
#         0/1 corresponds to a normalization where each element/path has an equal contribution to the forward propagation.
#     gradient_normalization (str or float): Normalization of the gradients, ``element`` or ``path``.
#         0/1 corresponds to a normalization where each element/path has an equal contribution to the learning.
# File:           ~/miniconda3/envs/avid/lib/python3.12/site-packages/e3nn_jax/_src/legacy/core_tensor_product.py
# Type:           type
# Subclasses:

# %%
jax.make_jaxpr(tpw)(x, y_sh, w)
# Out:
# { lambda ; a:f32[32,1,480] b:f32[32,4,25] c:f32[32,4,60416]. let
#     d:f32[32,4,480] = pjit[
#       name=tpw
#       jaxpr={ lambda e:f32[1,1,1] f:f32[1,3,3] g:f32[1,5,5] h:f32[1,7,7] i:f32[1,9,9]
#           j:f32[3,1,3] k:f32[3,3,1] l:f32[3,3,3] m:f32[3,3,5] n:f32[3,5,3] o:f32[3,5,5]
#           p:f32[3,5,7] q:f32[3,7,5] r:f32[3,7,7] s:f32[3,7,9] t:f32[3,9,7] u:f32[3,9,9]
#           v:f32[5,1,5] w:f32[5,3,3] x:f32[5,3,5] y:f32[5,3,7] z:f32[5,5,1] ba:f32[5,5,3]
#           bb:f32[5,5,5] bc:f32[5,5,7] bd:f32[5,5,9] be:f32[5,7,3] bf:f32[5,7,5] bg:f32[5,7,7]
#           bh:f32[5,7,9] bi:f32[5,9,5] bj:f32[5,9,7] bk:f32[5,9,9]; bl:f32[32,1,480]
#           bm:f32[32,4,25] bn:f32[32,4,60416]. let
#           bo:f32[32,480] = squeeze[dimensions=(1,)] bl
#           _:f32[32,4,480] = broadcast_in_dim[
#             broadcast_dimensions=(0, 2)
#             shape=(32, 4, 480)
#           ] bo
#           bp:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           bq:f32[32,1,128] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 1, 128)
#             unique_indices=True
#           ] bl bp
#           br:f32[32,1,128,1] = reshape[
#             dimensions=None
#             new_sizes=(32, 1, 128, 1)
#           ] bq
#           bs:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 128
#           bt:f32[32,1,192] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 1, 192)
#             unique_indices=True
#           ] bl bs
#           bu:f32[32,1,64,3] = reshape[dimensions=None new_sizes=(32, 1, 64, 3)] bt
#           bv:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 320
#           bw:f32[32,1,160] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 1, 160)
#             unique_indices=True
#           ] bl bv
#           bx:f32[32,1,32,5] = reshape[dimensions=None new_sizes=(32, 1, 32, 5)] bw
#           by:f32[32,128,1] = squeeze[dimensions=(1,)] br
#           bz:f32[32,4,128,1] = broadcast_in_dim[
#             broadcast_dimensions=(0, 2, 3)
#             shape=(32, 4, 128, 1)
#           ] by
#           ca:f32[32,64,3] = squeeze[dimensions=(1,)] bu
#           cb:f32[32,4,64,3] = broadcast_in_dim[
#             broadcast_dimensions=(0, 2, 3)
#             shape=(32, 4, 64, 3)
#           ] ca
#           cc:f32[32,32,5] = squeeze[dimensions=(1,)] bx
#           cd:f32[32,4,32,5] = broadcast_in_dim[
#             broadcast_dimensions=(0, 2, 3)
#             shape=(32, 4, 32, 5)
#           ] cc
#           ce:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 0
#           cf:f32[32,4,1] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 4, 1)
#             unique_indices=True
#           ] bm ce
#           cg:f32[32,4,1,1] = reshape[dimensions=None new_sizes=(32, 4, 1, 1)] cf
#           ch:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 1
#           ci:f32[32,4,3] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 4, 3)
#             unique_indices=True
#           ] bm ch
#           cj:f32[32,4,1,3] = reshape[dimensions=None new_sizes=(32, 4, 1, 3)] ci
#           ck:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 4
#           cl:f32[32,4,5] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 4, 5)
#             unique_indices=True
#           ] bm ck
#           cm:f32[32,4,1,5] = reshape[dimensions=None new_sizes=(32, 4, 1, 5)] cl
#           cn:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 9
#           co:f32[32,4,7] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 4, 7)
#             unique_indices=True
#           ] bm cn
#           cp:f32[32,4,1,7] = reshape[dimensions=None new_sizes=(32, 4, 1, 7)] co
#           cq:i32[1] = broadcast_in_dim[broadcast_dimensions=() shape=(1,)] 16
#           cr:f32[32,4,9] = gather[
#             dimension_numbers=GatherDimensionNumbers(offset_dims=(0, 1, 2), collapsed_slice_dims=(), start_index_map=(2,))
#             fill_value=None
#             indices_are_sorted=True
#             mode=GatherScatterMode.PROMISE_IN_BOUNDS
#             slice_sizes=(32, 4, 9)
#             unique_indices=True
#           ] bm cq
#           cs:f32[32,4,1,9] = reshape[dimensions=None new_sizes=(32, 4, 1, 9)] cr
#           ct:f32[32,4,128] = reshape[dimensions=None new_sizes=(32, 4, 128)] bz
#           cu:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] cb
#           cv:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] cd
#           _:f32[32,4,480] = concatenate[dimension=2] ct cu cv
#           cw:f32[32,4,1] = reshape[dimensions=None new_sizes=(32, 4, 1)] cg
#           cx:f32[32,4,3] = reshape[dimensions=None new_sizes=(32, 4, 3)] cj
#           cy:f32[32,4,5] = reshape[dimensions=None new_sizes=(32, 4, 5)] cm
#           cz:f32[32,4,7] = reshape[dimensions=None new_sizes=(32, 4, 7)] cp
#           da:f32[32,4,9] = reshape[dimensions=None new_sizes=(32, 4, 9)] cs
#           _:f32[32,4,25] = concatenate[dimension=2] cw cx cy cz da
#           db:f32[] = sqrt 1.0
#           dc:f32[] = convert_element_type[new_dtype=float32 weak_type=False] db
#           dd:f32[1,1,1] = mul e dc
#           de:f32[1,1,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] dd cg
#           df:f32[32,4,1,1,128] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] de bz
#           dg:f32[32,4,128,1,1] = transpose[permutation=(0, 1, 4, 3, 2)] df
#           dh:f32[32,4,128,1] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 128, 1)
#           ] dg
#           di:f32[] = sqrt 3.0
#           dj:f32[] = convert_element_type[new_dtype=float32 weak_type=False] di
#           dk:f32[1,3,3] = mul f dj
#           dl:f32[1,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] dk cj
#           dm:f32[32,4,3,1,128] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] dl bz
#           dn:f32[32,4,128,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] dm
#           do:f32[32,4,128,3] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 128, 3)
#           ] dn
#           dp:f32[] = sqrt 5.0
#           dq:f32[] = convert_element_type[new_dtype=float32 weak_type=False] dp
#           dr:f32[1,5,5] = mul g dq
#           ds:f32[1,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] dr cm
#           dt:f32[32,4,5,1,128] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ds bz
#           du:f32[32,4,128,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] dt
#           dv:f32[32,4,128,5] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 128, 5)
#           ] du
#           dw:f32[] = sqrt 7.0
#           dx:f32[] = convert_element_type[new_dtype=float32 weak_type=False] dw
#           dy:f32[1,7,7] = mul h dx
#           dz:f32[1,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] dy cp
#           ea:f32[32,4,7,1,128] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] dz bz
#           eb:f32[32,4,128,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] ea
#           ec:f32[32,4,128,7] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 128, 7)
#           ] eb
#           ed:f32[] = sqrt 9.0
#           ee:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ed
#           ef:f32[1,9,9] = mul i ee
#           eg:f32[1,9,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] ef cs
#           eh:f32[32,4,9,1,128] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] eg bz
#           ei:f32[32,4,128,1,9] = transpose[permutation=(0, 1, 4, 3, 2)] eh
#           ej:f32[32,4,128,9] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 128, 9)
#           ] ei
#           ek:f32[] = sqrt 3.0
#           el:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ek
#           em:f32[3,1,3] = mul j el
#           en:f32[3,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] em cg
#           eo:f32[32,4,3,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] en cb
#           ep:f32[32,4,64,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] eo
#           eq:f32[32,4,64,3] = reshape[dimensions=None new_sizes=(32, 4, 64, 3)] ep
#           er:f32[] = sqrt 1.0
#           es:f32[] = convert_element_type[new_dtype=float32 weak_type=False] er
#           et:f32[3,3,1] = mul k es
#           eu:f32[3,1,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] et cj
#           ev:f32[32,4,1,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] eu cb
#           ew:f32[32,4,64,1,1] = transpose[permutation=(0, 1, 4, 3, 2)] ev
#           ex:f32[32,4,64,1] = reshape[dimensions=None new_sizes=(32, 4, 64, 1)] ew
#           ey:f32[] = sqrt 3.0
#           ez:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ey
#           fa:f32[3,3,3] = mul l ez
#           fb:f32[3,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] fa cj
#           fc:f32[32,4,3,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] fb cb
#           fd:f32[32,4,64,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] fc
#           fe:f32[32,4,64,3] = reshape[dimensions=None new_sizes=(32, 4, 64, 3)] fd
#           ff:f32[] = sqrt 5.0
#           fg:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ff
#           fh:f32[3,3,5] = mul m fg
#           fi:f32[3,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] fh cj
#           fj:f32[32,4,5,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] fi cb
#           fk:f32[32,4,64,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] fj
#           fl:f32[32,4,64,5] = reshape[dimensions=None new_sizes=(32, 4, 64, 5)] fk
#           fm:f32[] = sqrt 3.0
#           fn:f32[] = convert_element_type[new_dtype=float32 weak_type=False] fm
#           fo:f32[3,5,3] = mul n fn
#           fp:f32[3,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] fo cm
#           fq:f32[32,4,3,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] fp cb
#           fr:f32[32,4,64,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] fq
#           fs:f32[32,4,64,3] = reshape[dimensions=None new_sizes=(32, 4, 64, 3)] fr
#           ft:f32[] = sqrt 5.0
#           fu:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ft
#           fv:f32[3,5,5] = mul o fu
#           fw:f32[3,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] fv cm
#           fx:f32[32,4,5,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] fw cb
#           fy:f32[32,4,64,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] fx
#           fz:f32[32,4,64,5] = reshape[dimensions=None new_sizes=(32, 4, 64, 5)] fy
#           ga:f32[] = sqrt 7.0
#           gb:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ga
#           gc:f32[3,5,7] = mul p gb
#           gd:f32[3,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] gc cm
#           ge:f32[32,4,7,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] gd cb
#           gf:f32[32,4,64,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] ge
#           gg:f32[32,4,64,7] = reshape[dimensions=None new_sizes=(32, 4, 64, 7)] gf
#           gh:f32[] = sqrt 5.0
#           gi:f32[] = convert_element_type[new_dtype=float32 weak_type=False] gh
#           gj:f32[3,7,5] = mul q gi
#           gk:f32[3,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] gj cp
#           gl:f32[32,4,5,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] gk cb
#           gm:f32[32,4,64,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] gl
#           gn:f32[32,4,64,5] = reshape[dimensions=None new_sizes=(32, 4, 64, 5)] gm
#           go:f32[] = sqrt 7.0
#           gp:f32[] = convert_element_type[new_dtype=float32 weak_type=False] go
#           gq:f32[3,7,7] = mul r gp
#           gr:f32[3,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] gq cp
#           gs:f32[32,4,7,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] gr cb
#           gt:f32[32,4,64,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] gs
#           gu:f32[32,4,64,7] = reshape[dimensions=None new_sizes=(32, 4, 64, 7)] gt
#           gv:f32[] = sqrt 9.0
#           gw:f32[] = convert_element_type[new_dtype=float32 weak_type=False] gv
#           gx:f32[3,7,9] = mul s gw
#           gy:f32[3,9,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] gx cp
#           gz:f32[32,4,9,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] gy cb
#           ha:f32[32,4,64,1,9] = transpose[permutation=(0, 1, 4, 3, 2)] gz
#           hb:f32[32,4,64,9] = reshape[dimensions=None new_sizes=(32, 4, 64, 9)] ha
#           hc:f32[] = sqrt 7.0
#           hd:f32[] = convert_element_type[new_dtype=float32 weak_type=False] hc
#           he:f32[3,9,7] = mul t hd
#           hf:f32[3,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] he cs
#           hg:f32[32,4,7,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] hf cb
#           hh:f32[32,4,64,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] hg
#           hi:f32[32,4,64,7] = reshape[dimensions=None new_sizes=(32, 4, 64, 7)] hh
#           hj:f32[] = sqrt 9.0
#           hk:f32[] = convert_element_type[new_dtype=float32 weak_type=False] hj
#           hl:f32[3,9,9] = mul u hk
#           hm:f32[3,9,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] hl cs
#           hn:f32[32,4,9,1,64] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] hm cb
#           ho:f32[32,4,64,1,9] = transpose[permutation=(0, 1, 4, 3, 2)] hn
#           hp:f32[32,4,64,9] = reshape[dimensions=None new_sizes=(32, 4, 64, 9)] ho
#           hq:f32[] = sqrt 5.0
#           hr:f32[] = convert_element_type[new_dtype=float32 weak_type=False] hq
#           hs:f32[5,1,5] = mul v hr
#           ht:f32[5,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] hs cg
#           hu:f32[32,4,5,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ht cd
#           hv:f32[32,4,32,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] hu
#           hw:f32[32,4,32,5] = reshape[dimensions=None new_sizes=(32, 4, 32, 5)] hv
#           hx:f32[] = sqrt 3.0
#           hy:f32[] = convert_element_type[new_dtype=float32 weak_type=False] hx
#           hz:f32[5,3,3] = mul w hy
#           ia:f32[5,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] hz cj
#           ib:f32[32,4,3,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ia cd
#           ic:f32[32,4,32,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] ib
#           id:f32[32,4,32,3] = reshape[dimensions=None new_sizes=(32, 4, 32, 3)] ic
#           ie:f32[] = sqrt 5.0
#           if:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ie
#           ig:f32[5,3,5] = mul x if
#           ih:f32[5,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] ig cj
#           ii:f32[32,4,5,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ih cd
#           ij:f32[32,4,32,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] ii
#           ik:f32[32,4,32,5] = reshape[dimensions=None new_sizes=(32, 4, 32, 5)] ij
#           il:f32[] = sqrt 7.0
#           im:f32[] = convert_element_type[new_dtype=float32 weak_type=False] il
#           in:f32[5,3,7] = mul y im
#           io:f32[5,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] in cj
#           ip:f32[32,4,7,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] io cd
#           iq:f32[32,4,32,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] ip
#           ir:f32[32,4,32,7] = reshape[dimensions=None new_sizes=(32, 4, 32, 7)] iq
#           is:f32[] = sqrt 1.0
#           it:f32[] = convert_element_type[new_dtype=float32 weak_type=False] is
#           iu:f32[5,5,1] = mul z it
#           iv:f32[5,1,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] iu cm
#           iw:f32[32,4,1,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] iv cd
#           ix:f32[32,4,32,1,1] = transpose[permutation=(0, 1, 4, 3, 2)] iw
#           iy:f32[32,4,32,1] = reshape[dimensions=None new_sizes=(32, 4, 32, 1)] ix
#           iz:f32[] = sqrt 3.0
#           ja:f32[] = convert_element_type[new_dtype=float32 weak_type=False] iz
#           jb:f32[5,5,3] = mul ba ja
#           jc:f32[5,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] jb cm
#           jd:f32[32,4,3,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] jc cd
#           je:f32[32,4,32,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] jd
#           jf:f32[32,4,32,3] = reshape[dimensions=None new_sizes=(32, 4, 32, 3)] je
#           jg:f32[] = sqrt 5.0
#           jh:f32[] = convert_element_type[new_dtype=float32 weak_type=False] jg
#           ji:f32[5,5,5] = mul bb jh
#           jj:f32[5,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] ji cm
#           jk:f32[32,4,5,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] jj cd
#           jl:f32[32,4,32,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] jk
#           jm:f32[32,4,32,5] = reshape[dimensions=None new_sizes=(32, 4, 32, 5)] jl
#           jn:f32[] = sqrt 7.0
#           jo:f32[] = convert_element_type[new_dtype=float32 weak_type=False] jn
#           jp:f32[5,5,7] = mul bc jo
#           jq:f32[5,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] jp cm
#           jr:f32[32,4,7,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] jq cd
#           js:f32[32,4,32,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] jr
#           jt:f32[32,4,32,7] = reshape[dimensions=None new_sizes=(32, 4, 32, 7)] js
#           ju:f32[] = sqrt 9.0
#           jv:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ju
#           jw:f32[5,5,9] = mul bd jv
#           jx:f32[5,9,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] jw cm
#           jy:f32[32,4,9,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] jx cd
#           jz:f32[32,4,32,1,9] = transpose[permutation=(0, 1, 4, 3, 2)] jy
#           ka:f32[32,4,32,9] = reshape[dimensions=None new_sizes=(32, 4, 32, 9)] jz
#           kb:f32[] = sqrt 3.0
#           kc:f32[] = convert_element_type[new_dtype=float32 weak_type=False] kb
#           kd:f32[5,7,3] = mul be kc
#           ke:f32[5,3,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] kd cp
#           kf:f32[32,4,3,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ke cd
#           kg:f32[32,4,32,1,3] = transpose[permutation=(0, 1, 4, 3, 2)] kf
#           kh:f32[32,4,32,3] = reshape[dimensions=None new_sizes=(32, 4, 32, 3)] kg
#           ki:f32[] = sqrt 5.0
#           kj:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ki
#           kk:f32[5,7,5] = mul bf kj
#           kl:f32[5,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] kk cp
#           km:f32[32,4,5,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] kl cd
#           kn:f32[32,4,32,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] km
#           ko:f32[32,4,32,5] = reshape[dimensions=None new_sizes=(32, 4, 32, 5)] kn
#           kp:f32[] = sqrt 7.0
#           kq:f32[] = convert_element_type[new_dtype=float32 weak_type=False] kp
#           kr:f32[5,7,7] = mul bg kq
#           ks:f32[5,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] kr cp
#           kt:f32[32,4,7,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ks cd
#           ku:f32[32,4,32,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] kt
#           kv:f32[32,4,32,7] = reshape[dimensions=None new_sizes=(32, 4, 32, 7)] ku
#           kw:f32[] = sqrt 9.0
#           kx:f32[] = convert_element_type[new_dtype=float32 weak_type=False] kw
#           ky:f32[5,7,9] = mul bh kx
#           kz:f32[5,9,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] ky cp
#           la:f32[32,4,9,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] kz cd
#           lb:f32[32,4,32,1,9] = transpose[permutation=(0, 1, 4, 3, 2)] la
#           lc:f32[32,4,32,9] = reshape[dimensions=None new_sizes=(32, 4, 32, 9)] lb
#           ld:f32[] = sqrt 5.0
#           le:f32[] = convert_element_type[new_dtype=float32 weak_type=False] ld
#           lf:f32[5,9,5] = mul bi le
#           lg:f32[5,5,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] lf cs
#           lh:f32[32,4,5,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] lg cd
#           li:f32[32,4,32,1,5] = transpose[permutation=(0, 1, 4, 3, 2)] lh
#           lj:f32[32,4,32,5] = reshape[dimensions=None new_sizes=(32, 4, 32, 5)] li
#           lk:f32[] = sqrt 7.0
#           ll:f32[] = convert_element_type[new_dtype=float32 weak_type=False] lk
#           lm:f32[5,9,7] = mul bj ll
#           ln:f32[5,7,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] lm cs
#           lo:f32[32,4,7,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] ln cd
#           lp:f32[32,4,32,1,7] = transpose[permutation=(0, 1, 4, 3, 2)] lo
#           lq:f32[32,4,32,7] = reshape[dimensions=None new_sizes=(32, 4, 32, 7)] lp
#           lr:f32[] = sqrt 9.0
#           ls:f32[] = convert_element_type[new_dtype=float32 weak_type=False] lr
#           lt:f32[5,9,9] = mul bk ls
#           lu:f32[5,9,32,4,1] = dot_general[
#             dimension_numbers=(([1], [3]), ([], []))
#             preferred_element_type=float32
#           ] lt cs
#           lv:f32[32,4,9,1,32] = dot_general[
#             dimension_numbers=(([0], [3]), ([2, 3], [0, 1]))
#             preferred_element_type=float32
#           ] lu cd
#           lw:f32[32,4,32,1,9] = transpose[permutation=(0, 1, 4, 3, 2)] lv
#           lx:f32[32,4,32,9] = reshape[dimensions=None new_sizes=(32, 4, 32, 9)] lw
#           ly:f32[32,4,128] = reshape[dimensions=None new_sizes=(32, 4, 128)] dh
#           lz:f32[32,4,384] = reshape[dimensions=None new_sizes=(32, 4, 384)] do
#           ma:f32[32,4,640] = reshape[dimensions=None new_sizes=(32, 4, 640)] dv
#           mb:f32[32,4,896] = reshape[dimensions=None new_sizes=(32, 4, 896)] ec
#           mc:f32[32,4,1152] = reshape[dimensions=None new_sizes=(32, 4, 1152)] ej
#           md:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] eq
#           me:f32[32,4,64] = reshape[dimensions=None new_sizes=(32, 4, 64)] ex
#           mf:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] fe
#           mg:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] fl
#           mh:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] fs
#           mi:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] fz
#           mj:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] gg
#           mk:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] gn
#           ml:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] gu
#           mm:f32[32,4,576] = reshape[dimensions=None new_sizes=(32, 4, 576)] hb
#           mn:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] hi
#           mo:f32[32,4,576] = reshape[dimensions=None new_sizes=(32, 4, 576)] hp
#           mp:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] hw
#           mq:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] id
#           mr:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] ik
#           ms:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] ir
#           mt:f32[32,4,32] = reshape[dimensions=None new_sizes=(32, 4, 32)] iy
#           mu:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] jf
#           mv:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] jm
#           mw:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] jt
#           mx:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] ka
#           my:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] kh
#           mz:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] ko
#           na:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] kv
#           nb:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] lc
#           nc:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] lj
#           nd:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] lq
#           ne:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] lx
#           nf:f32[32,4,6720] = concatenate[dimension=2] ly lz ma mb mc md me mf mg
#             mh mi mj mk ml mm mn
#           ng:f32[32,4,3168] = concatenate[dimension=2] mo mp mq mr ms mt mu mv mw
#             mx my mz na nb nc nd
#           _:f32[32,4,10176] = concatenate[dimension=2] nf ng ne
#           nh:f32[32,4,128] = reshape[dimensions=None new_sizes=(32, 4, 128)] dh
#           ni:f32[32,4,64] = reshape[dimensions=None new_sizes=(32, 4, 64)] ex
#           nj:f32[32,4,32] = reshape[dimensions=None new_sizes=(32, 4, 32)] iy
#           nk:f32[32,4,384] = reshape[dimensions=None new_sizes=(32, 4, 384)] do
#           nl:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] eq
#           nm:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] fs
#           nn:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] id
#           no:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] kh
#           np:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] fe
#           nq:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] jf
#           nr:f32[32,4,640] = reshape[dimensions=None new_sizes=(32, 4, 640)] dv
#           ns:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] fl
#           nt:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] gn
#           nu:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] hw
#           nv:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] jm
#           nw:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] lj
#           nx:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] fz
#           ny:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] ik
#           nz:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] ko
#           oa:f32[32,4,896] = reshape[dimensions=None new_sizes=(32, 4, 896)] ec
#           ob:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] gg
#           oc:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] hi
#           od:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] ir
#           oe:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] kv
#           of:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] gu
#           og:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] jt
#           oh:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] lq
#           oi:f32[32,4,1152] = reshape[dimensions=None new_sizes=(32, 4, 1152)] ej
#           oj:f32[32,4,576] = reshape[dimensions=None new_sizes=(32, 4, 576)] hb
#           ok:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] ka
#           ol:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] lx
#           om:f32[32,4,576] = reshape[dimensions=None new_sizes=(32, 4, 576)] hp
#           on:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] lc
#           oo:f32[32,4,3232] = concatenate[dimension=2] nh ni nj nk nl nm nn no np
#             nq nr ns nt nu nv nw
#           op:f32[32,4,6656] = concatenate[dimension=2] nx ny nz oa ob oc od oe of
#             og oh oi oj ok ol om
#           _:f32[32,4,10176] = concatenate[dimension=2] oo op on
#           oq:f32[32,4,128] = reshape[dimensions=None new_sizes=(32, 4, 128)] dh
#           or:f32[32,4,64] = reshape[dimensions=None new_sizes=(32, 4, 64)] ex
#           os:f32[32,4,32] = reshape[dimensions=None new_sizes=(32, 4, 32)] iy
#           ot:f32[32,4,384] = reshape[dimensions=None new_sizes=(32, 4, 384)] do
#           ou:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] eq
#           ov:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] fs
#           ow:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] id
#           ox:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] kh
#           oy:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] fe
#           oz:f32[32,4,96] = reshape[dimensions=None new_sizes=(32, 4, 96)] jf
#           pa:f32[32,4,640] = reshape[dimensions=None new_sizes=(32, 4, 640)] dv
#           pb:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] fl
#           pc:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] gn
#           pd:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] hw
#           pe:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] jm
#           pf:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] lj
#           pg:f32[32,4,320] = reshape[dimensions=None new_sizes=(32, 4, 320)] fz
#           ph:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] ik
#           pi:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] ko
#           pj:f32[32,4,896] = reshape[dimensions=None new_sizes=(32, 4, 896)] ec
#           pk:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] gg
#           pl:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] hi
#           pm:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] ir
#           pn:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] kv
#           po:f32[32,4,448] = reshape[dimensions=None new_sizes=(32, 4, 448)] gu
#           pp:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] jt
#           pq:f32[32,4,224] = reshape[dimensions=None new_sizes=(32, 4, 224)] lq
#           pr:f32[32,4,1152] = reshape[dimensions=None new_sizes=(32, 4, 1152)] ej
#           ps:f32[32,4,576] = reshape[dimensions=None new_sizes=(32, 4, 576)] hb
#           pt:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] ka
#           pu:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] lx
#           pv:f32[32,4,576] = reshape[dimensions=None new_sizes=(32, 4, 576)] hp
#           pw:f32[32,4,288] = reshape[dimensions=None new_sizes=(32, 4, 288)] lc
#           px:f32[32,4,3232] = concatenate[dimension=2] oq or os ot ou ov ow ox oy
#             oz pa pb pc pd pe pf
#           py:f32[32,4,6656] = concatenate[dimension=2] pg ph pi pj pk pl pm pn po
#             pp pq pr ps pt pu pv
#           _:f32[32,4,10176] = concatenate[dimension=2] px py pw
#           pz:f32[32,4,192,1] = concatenate[dimension=2] dh ex
#           qa:f32[32,4,224,1] = concatenate[dimension=2] pz iy
#           qb:f32[32,4,192,3] = concatenate[dimension=2] do eq
#           qc:f32[32,4,256,3] = concatenate[dimension=2] qb fs
#           qd:f32[32,4,288,3] = concatenate[dimension=2] qc id
#           qe:f32[32,4,320,3] = concatenate[dimension=2] qd kh
#           _:f32[32,4,96,3] = concatenate[dimension=2] fe jf
#           qf:f32[32,4,192,5] = concatenate[dimension=2] dv fl
#           qg:f32[32,4,256,5] = concatenate[dimension=2] qf gn
#           qh:f32[32,4,288,5] = concatenate[dimension=2] qg hw
#           qi:f32[32,4,320,5] = concatenate[dimension=2] qh jm
#           qj:f32[32,4,352,5] = concatenate[dimension=2] qi lj
#           qk:f32[32,4,96,5] = concatenate[dimension=2] fz ik
#           _:f32[32,4,128,5] = concatenate[dimension=2] qk ko
#           ql:f32[32,4,192,7] = concatenate[dimension=2] ec gg
#           qm:f32[32,4,256,7] = concatenate[dimension=2] ql hi
#           qn:f32[32,4,288,7] = concatenate[dimension=2] qm ir
#           _:f32[32,4,320,7] = concatenate[dimension=2] qn kv
#           qo:f32[32,4,96,7] = concatenate[dimension=2] gu jt
#           _:f32[32,4,128,7] = concatenate[dimension=2] qo lq
#           qp:f32[32,4,192,9] = concatenate[dimension=2] ej hb
#           qq:f32[32,4,224,9] = concatenate[dimension=2] qp ka
#           _:f32[32,4,256,9] = concatenate[dimension=2] qq lx
#           _:f32[32,4,96,9] = concatenate[dimension=2] hp lc
#           qr:f32[32,4,28672] = slice[
#             limit_indices=(32, 4, 28672)
#             start_indices=(0, 0, 0)
#             strides=None
#           ] bn
#           qs:f32[32,4,224,128] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 224, 128)
#           ] qr
#           qt:f32[32,4,20480] = slice[
#             limit_indices=(32, 4, 49152)
#             start_indices=(0, 0, 28672)
#             strides=None
#           ] bn
#           qu:f32[32,4,320,64] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 320, 64)
#           ] qt
#           qv:f32[32,4,11264] = slice[
#             limit_indices=(32, 4, 60416)
#             start_indices=(0, 0, 49152)
#             strides=None
#           ] bn
#           qw:f32[32,4,352,32] = reshape[
#             dimensions=None
#             new_sizes=(32, 4, 352, 32)
#           ] qv
#           qx:f32[32,4,128,1] = dot_general[
#             dimension_numbers=(([2], [2]), ([0, 1], [0, 1]))
#             preferred_element_type=float32
#           ] qs qa
#           qy:f32[32,4,128,1] = mul 0.06681530922651291 qx
#           qz:f32[32,4,64,3] = dot_general[
#             dimension_numbers=(([2], [2]), ([0, 1], [0, 1]))
#             preferred_element_type=float32
#           ] qu qe
#           ra:f32[32,4,64,3] = mul 0.055901698768138885 qz
#           rb:f32[32,4,32,5] = dot_general[
#             dimension_numbers=(([2], [2]), ([0, 1], [0, 1]))
#             preferred_element_type=float32
#           ] qw qj
#           rc:f32[32,4,32,5] = mul 0.05330017954111099 rb
#           rd:f32[32,4,128] = reshape[dimensions=None new_sizes=(32, 4, 128)] qy
#           re:f32[32,4,192] = reshape[dimensions=None new_sizes=(32, 4, 192)] ra
#           rf:f32[32,4,160] = reshape[dimensions=None new_sizes=(32, 4, 160)] rc
#           rg:f32[32,4,480] = concatenate[dimension=2] rd re rf
#         in (rg,) }
#     ] a b c
#   in (d,) }
